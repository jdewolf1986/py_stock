# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('stock2own_scraped.csv')
series = df['url']

# countries = ['US','AU','CA','CH','DE','ES','GB']

subsetter = np.where((series.str.contains('AU')) | (series.str.contains('GB')))
subset = series.iloc[subsetter]

subset

#TODO: Add more countries and filter to perfection
# Out:
# 106     https://www.stock2own.com/StockAnalysis/Stock/...
# 113     https://www.stock2own.com/StockAnalysis/Stock/...
# 115     https://www.stock2own.com/StockAnalysis/Stock/...
# 116     https://www.stock2own.com/StockAnalysis/Stock/...
# 124     https://www.stock2own.com/StockAnalysis/Stock/...
#                               ...
# 1801    https://www.stock2own.com/StockAnalysis/Stock/...
# 1802    https://www.stock2own.com/StockAnalysis/Stock/...
# 1803    https://www.stock2own.com/StockAnalysis/Stock/...
# 1807    https://www.stock2own.com/StockAnalysis/Stock/...
# 1809    https://www.stock2own.com/StockAnalysis/Stock/...
# Name: url, Length: 118, dtype: object

# %%
# read stock list

for url in urls:

    dfs = pd.read_html(url)
    # annual statements:
    dfs[0]
    # quarterly statements:
    dfs[1]
    # PE and EPS
    dfs[2]
    # Value Price & Investment Recovery Time
    dfs[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-493bf7a03c44> in <module>
#       1 # read stock list
#       2
# ----> 3 for url in urls:
#       4
#       5     dfs = pd.read_html(url)
#
# NameError: name 'urls' is not defined

# %%
# read html tables from url
url = 'https://www.stock2own.com/StockAnalysis/Stock/US/AAPL?w=1903'

dfs = pd.read_html(url)
# annual statements:
dfs[0]
# quarterly statements:
dfs[1]
# PE and EPS
dfs[2]
# Value Price & Investment Recovery Time
dfs[3]

# %%
dfs[0]
